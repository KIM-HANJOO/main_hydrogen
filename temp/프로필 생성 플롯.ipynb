# %%
import os
ndir = os.getcwd()
os.chdir('C:\\Users\\joo09\\Documents\\GitHub\\main_hydrogen\\module')

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import model_library as lib

os.chdir(ndir)

df1 = lib.read_excel('24번째 세대 전력프로필(평일).xlsx')
df2 = lib.read_excel('24번째 세대 전력프로필(주말).xlsx')

print(df1)

print('\n', df2)
# Out:
#             1         2         3         4         5         6         7  \
# 0    0.021459  0.012661  0.013668  0.014711  0.017460  0.019621  0.020575
# 1    0.018097  0.013604  0.009384  0.014031  0.016353  0.007918  0.001878
# 2    0.027359  0.013375  0.006148  0.012210  0.005703  0.019703  0.020067
# 3    0.032152  0.014864  0.012656  0.014212  0.008050  0.003572  0.011245
# 4    0.022060  0.015985  0.000361  0.002057  0.013511  0.009119  0.000348
# ..        ...       ...       ...       ...       ...       ...       ...
# 256  0.024488  0.011816  0.014229  0.014954  0.015105  0.010209  0.012364
# 257  0.029346  0.023542  0.011812  0.010958  0.018984  0.012216  0.023802
# 258  0.013666  0.011612  0.011918  0.017307  0.016473  0.022414  0.015209
# 259  0.039950  0.019409  0.011705  0.013247  0.026983  0.028958  0.014472
# 260  0.015775  0.016545  0.010102  0.012059  0.014820  0.012515  0.014514
#
#             8         9        10  ...        15        16        17  \
# ...

# %%
# df1.reset_index(drop = True, inplace = True)
# print(df1)
hours = []
for i in range(1, 25) :
    hours.append(i)
hours_2 = []
for i in range(25, 49) :
    hours_2.append(i)


for i in range(df1.shape[0]) :
    plt.plot(hours, df1.loc[i, :])


plt.xlim(1, 24)
plt.ylim(-0.01, 0.16)
plt.xticks(hours, rotation = 90)
plt.grid()
plt.title('random sample(weekday)')
plt.show()


for i in range(df2.shape[0]) :
    plt.plot(hours, df2.loc[i, :])

plt.xlim(1, 24)
plt.ylim(-0.01, 0.16)
plt.xticks(hours, rotation = 90)
plt.grid()
plt.title('random sample(weekend)')
plt.show()

# %%
org = lib.read_excel('profile_48_group_0.xlsx')
org = org.loc[:, '1' : '24']
for i in range(org.shape[0]) :
    plt.plot(hours, org.loc[i, :])

plt.xlim(1, 24)
plt.xticks(hours, rotation = 90)
plt.grid()
plt.title('actual sample')
plt.show()

# %%
g0dir = "C:\\Users\\joo09\\Documents\\GitHub\\main_hydrogen\\시설군별\\model3_cluster\\교육시설\\group_0_model3"
os.chdir(g0dir + '\\주중')
ap1 = lib.read_excel('[P.교육 서비스업(85)]_107_주중_봄가을.xlsx')
os.chdir(g0dir + '\\주말')
ap2 = lib.read_excel('[P.교육 서비스업(85)]_107_주말_봄가을.xlsx')


for i in range(ap1.shape[0]) :
    plt.plot(hours, ap1.loc[i, :])
    
plt.xlim(1, 24)
plt.ylim(-0.01, 0.20)
plt.xticks(hours, rotation = 90)
plt.grid()
plt.title('actual sample(weekday)')
plt.show()


for i in range(ap2.shape[0]) :
    plt.plot(hours, ap2.loc[i, :])

plt.xlim(1, 24)
plt.ylim(-0.01, 0.20)
plt.xticks(hours, rotation = 90)
plt.grid()
plt.title('actual sample(weekend)')
plt.show()

# %%
g0dir = "C:\\Users\\joo09\\Documents\\GitHub\\main_hydrogen\\시설군별\\model3_cluster\\교육시설\\group_0_model3"
os.chdir(g0dir + '\\주중')
ap1 = lib.read_excel('[P.교육 서비스업(85)]_110_주중_봄가을.xlsx')
os.chdir(g0dir + '\\주말')
ap2 = lib.read_excel('[P.교육 서비스업(85)]_110_주말_봄가을.xlsx')


for i in range(ap1.shape[0]) :
    plt.plot(hours, ap1.loc[i, :])
    
plt.xlim(1, 24)
plt.ylim(-0.01, 0.20)
plt.xticks(hours, rotation = 90)
plt.grid()
plt.title('actual sample(weekday)')
plt.show()


for i in range(ap2.shape[0]) :
    plt.plot(hours, ap2.loc[i, :])

plt.xlim(1, 24)
plt.ylim(-0.01, 0.20)
plt.xticks(hours, rotation = 90)
plt.grid()
plt.title('actual sample(weekend)')
plt.show()
